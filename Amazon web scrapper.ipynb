# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept-Language": "en-US,en;q=0.9",
}

url = "https://www.amazon.com/Nautica-Sleeve-Pocket-T-Shirt-Bright/dp/B07HRCFGG7/ref=sr_1_3?crid=2ZOW4IV2RQJMV&dib=eyJ2IjoiMSJ9.FaQ8v6zBEvx5mr8b5tr1QlFHafb5GPqDAvWf4tDFbBO9hZo-c7V2kz9Ma3rbq9HJ14w3kOoM5JQ3nHtmICEAUx7VxahoSCewOuMb5XnXwQ6SJ4TiZYAwNGkwm7FZinqTu3TV3m1t_aWDwtehqRBjEXdKfEPikoSvUhgZUebrRj26D8ElK3CgdG6IauSSgLrwcyp2dQsA2aX6twH9G4rG0JbK6OVpvT9lbkDCTHyE-_Nv-CYwEegTy8jsQBtUrQ9ewpSb8pNqiqoMoX5jX_VsLxKb9EXtV3tBLLVFv2hIOM0.2XkRgMaDf55aBrZ665-1mipCBrBhfISCsV1JKdat4DY&dib_tag=se&keywords=t%2B-shirts%2Bfor%2Bmen&qid=1764427258&sprefix=t%2Bshirts%2Bfor%2Bmen%2B%2Caps%2C473&sr=8-3&th=1&psc=1"
page = requests.get(url, headers=headers).text
soup = BeautifulSoup(page, "html.parser")

title= soup.find("span", id="productTitle").get_text(strip=True)

print(title)

price = soup.find("span", class_="a-price-whole").get_text(strip=True)

print(price)

price_cent = soup.find("span", class_="a-price-fraction").get_text(strip=True)
print(price_cent)

complete_price = price + price_cent
print(complete_price)
# Out:
# Nautica Men's Classic Fit Pocket T-Shirt
# 13.
# 88
# 13.88

# %%
# Create a Timestamp for your output to track when data was collected

import datetime

today = datetime.date.today()

print(today)
# Out:
# 2025-11-29

# %%
import csv

header = ["Title", "Price", "Date"]

data = [title, complete_price, today] 

with open('Amazon_project.csv', 'w', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd 

df =pd.read_csv(r"C:\Users\user\Downloads\Amazon_project.csv")

df
# Out:
#                                        Title      Price        Date
# 0   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 1   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 2   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 3   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 4   Nautica Men's Classic Fit Pocket T-Shirt  20,093.94  2025-11-29
# 5   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 6   Nautica Men's Classic Fit Pocket T-Shirt  20,093.94  2025-11-29
# 7   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 8   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 9   Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 10  Nautica Men's Classic Fit Pocket T-Shirt  20,093.94  2025-11-29
# 11  Nautica Men's Classic Fit Pocket T-Shirt      13.88  2025-11-29
# 12  Nautica Men's Classic Fit Pocket T-Shirt  20,093.94  2025-11-29
# ...

# %%
#now appending the table 

with open('Amazon_project.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#Combine all of the above code into one function


def check_price():
    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)",
    "Accept-Language": "en-US,en;q=0.9",}

    url = "https://www.amazon.com/Nautica-Sleeve-Pocket-T-Shirt-Bright/dp/B07HRCFGG7/ref=sr_1_3?crid=2ZOW4IV2RQJMV&dib=eyJ2IjoiMSJ9.FaQ8v6zBEvx5mr8b5tr1QlFHafb5GPqDAvWf4tDFbBO9hZo-c7V2kz9Ma3rbq9HJ14w3kOoM5JQ3nHtmICEAUx7VxahoSCewOuMb5XnXwQ6SJ4TiZYAwNGkwm7FZinqTu3TV3m1t_aWDwtehqRBjEXdKfEPikoSvUhgZUebrRj26D8ElK3CgdG6IauSSgLrwcyp2dQsA2aX6twH9G4rG0JbK6OVpvT9lbkDCTHyE-_Nv-CYwEegTy8jsQBtUrQ9ewpSb8pNqiqoMoX5jX_VsLxKb9EXtV3tBLLVFv2hIOM0.2XkRgMaDf55aBrZ665-1mipCBrBhfISCsV1JKdat4DY&dib_tag=se&keywords=t%2B-shirts%2Bfor%2Bmen&qid=1764427258&sprefix=t%2Bshirts%2Bfor%2Bmen%2B%2Caps%2C473&sr=8-3&th=1&psc=1"
    page = requests.get(url, headers=headers).text
    soup = BeautifulSoup(page, "html.parser")

    title= soup.find("span", id="productTitle").get_text(strip=True)

    price = soup.find("span", class_="a-price-whole").get_text(strip=True)

    price_cent = soup.find("span", class_="a-price-fraction").get_text(strip=True)

    complete_price = price + price_cent
    
    import datetime

    today = datetime.date.today()
    
    import csv

    header = ["Title", "Price", "Date"]

    data = [title, complete_price, today] 

    with open('Amazon_project.csv', 'a+', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
c
# Out:
# <function __main__.check_price()>

# %%
# Runs check_price after a set time and inputs data into your CSV

while(True):
    check_price()
    time.sleep(86500)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\user\Downloads\Amazon_project.csv")

print(df)

# %%
# If uou want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('boboolaribigbe@gmail.com','olamiposi123')
    
    subject = "The Shirt you want is below $15! Now is your chance to buy!"
    body = "posi, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams. Don't mess it up! Link here: https://www.amazon.com/Funny-Data-Systems-Business-Analyst/dp/B07FNW9FGJ/ref=sr_1_3?dchild=1&keywords=data+analyst+tshirt&qid=1626655184&sr=8-3"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'boboolaribigbe@gmail.com',
        msg
     
    )
